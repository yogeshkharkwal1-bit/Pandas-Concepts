# %% [markdown]
# ## SERIES >>>  1D labelled arrays
#
# ## Dataframe >> 2D lablled array likea table form

# %%
import numpy as np
import pandas as pd

# %%
info={
    "Name":["Rahul","Yogi","Chndu"],
    "Cgpa":[9,8,9.8]

}

df=pd.DataFrame(info)

print(df)
# Out:
#     Name  Cgpa
# 0  Rahul   9.0
# 1   Yogi   8.0
# 2  Chndu   9.8

# %%
df
# Out:
#     Name  Cgpa
# 0  Rahul   9.0
# 1   Yogi   8.0
# 2  Chndu   9.8
